# %%
import numpy as  np
import pandas as pd

# %%
#loading dataset
sms=pd.read_csv("C:\Users\Yatharth Saxena\Downloads\Compressed\pycon-2016-tutorial-master\pycon-2016-tutorial-master\data\yelp.csv")

# %%
sms.head(10)
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 5  -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6  zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 7  hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      4
# 8  wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      4
# 9  nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
# 5  Quiessence is, simply put, beautiful.  Full wi...  review
# 6  Drop what you're doing and drive here. After I...  review
# 7  Luckily, I didn't have to travel far to make m...  review
# 8  Definitely come for Happy hour! Prices are ama...  review
# 9  Nobuo shows his unique talents with everything...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0
# 5  sqYN3lNgvPbPCTRsMFu27g     4       3      1
# 6  wFweIWhv2fREZV_dYkz_1g     7       7      4
# 7  1ieuYcKS7zeAv_U15AB13A     0       1      0
# 8  Vh_DlizgGhSqQh4qfZ2h6A     0       0      0
# 9  sUNkXg8-KFtCMQDV6zRzQg     0       1      0

# %%
sms_df = sms[['text','stars']].copy()
sms_df
# Out:
#                                                    text  stars
# 0     My wife took me here on my birthday for breakf...      5
# 1     I have no idea why some people give bad review...      5
# 2     love the gyro plate. Rice is so good and I als...      4
# 3     Rosie, Dakota, and I LOVE Chaparral Dog Park!!...      5
# 4     General Manager Scott Petello is a good egg!!!...      5
# 5     Quiessence is, simply put, beautiful.  Full wi...      4
# 6     Drop what you're doing and drive here. After I...      5
# 7     Luckily, I didn't have to travel far to make m...      4
# 8     Definitely come for Happy hour! Prices are ama...      4
# 9     Nobuo shows his unique talents with everything...      5
# 10    The oldish man who owns the store is as sweet ...      5
# 11    Wonderful Vietnamese sandwich shoppe. Their ba...      5
# 12    They have a limited time thing going on right ...      5
# 13    Good tattoo shop. Clean space, multiple artist...      4
# 14    I'm 2 weeks new to Phoenix. I looked up Irish ...      4
# 15    Was it worth the 21$ for a salad and small piz...      2
# 16    We went here on a Saturday afternoon and this ...      3
# 17    okay this is the best place EVER! i grew up sh...      5
# 18    I met a friend for lunch yesterday. \n\nLoved ...      3
# 19    They've gotten better and better for me in the...      4
# 20    DVAP....\n\nYou have to go at least once in yo...      3
# 21    This place shouldn't even be reviewed - becaus...      5
# 22    first time my friend and I went there... it wa...      5
# 23    U can go there n check the car out. If u wanna...      1
# 24    I love this place! I have been coming here for...      5
# 25    This place is great.  A nice little ole' fashi...      4
# 26    I love love LOVE this place. My boss (who is i...      5
# 27    Not that my review will mean much given the mo...      4
# 28    Came here for breakfast yesterday, it had been...      4
# 29    Always reliably good.  Great beer selection as...      4
# ...                                                 ...    ...
# 9970  This place is super cute lunch joint.  I had t...      5
# 9971  The staff is great, the food is great, even th...      5
# 9972  Yay, even though I miss living in Coronado I a...      4
# 9973  Wow!  Went on a Sunday around 11am - busy but ...      5
# 9974  If Cowboy Ciao is the best restaurant in Scott...      2
# 9975  When I lived in Phoenix, I was a regular at Fe...      5
# 9976  I was looking for chile rellenos and this plac...      3
# 9977  Why did I wait so long to try this neighborhoo...      5
# 9978  This is the place for a fabulos breakfast!! I ...      5
# 9979  Highly recommend. This is my second time here ...      5
# 9980  5 stars for the great $5 happy hour specials. ...      5
# 9981  We brought the entire family to Giuseppe's las...      5
# 9982  Best corned beef sandwich I've had anywhere at...      4
# 9983  3.5 stars. \n\nWe decided to check this place ...      3
# 9984  Went last night to Whore Foods to get basics t...      1
# 9985  Awesome food! Little pricey but delicious. Lov...      4
# 9986  I came here in December and look forward to my...      4
# 9987  The food is delicious.  The service:  discrimi...      1
# 9988  For our first time we had a great time! Our se...      4
# 9989  Great food and service! Country food at its best!      5
# 9990  Yes I do rock the hipster joints.  I dig this ...      5
# 9991  Only 4 stars? \n\n(A few notes: The folks that...      5
# 9992  I'm not normally one to jump at reviewing a ch...      5
# 9993  Judging by some of the reviews, maybe I went o...      4
# 9994  Let's see...what is there NOT to like about Su...      5
# 9995  First visit...Had lunch here today - used my G...      3
# 9996  Should be called house of deliciousness!\n\nI ...      4
# 9997  I recently visited Olive and Ivy for business ...      4
# 9998  My nephew just moved to Scottsdale recently so...      2
# 9999  4-5 locations.. all 4.5 star average.. I think...      5
#
# [10000 rows x 2 columns]

# %%
X=sms_df.text
y=sms_df.stars
print(X.shape)
print(y.shape)
# Out:
# (10000,)
# (10000,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.snowball import EnglishStemmer

stemmer = EnglishStemmer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

stem_vectorizer = CountVectorizer(analyzer=stemmed_words)
print(stem_vectorizer.fit_transform(X))
print(stem_vectorizer.get_feature_names())
# Out:
#   (0, 1728)	1
#   (0, 7724)	1
#   (0, 18004)	1
#   (0, 19244)	1
#   (0, 3148)	1
#   (0, 1258)	1
#   (0, 18007)	1
#   (0, 4203)	1
#   (0, 11132)	1
#   (0, 2674)	1
#   (0, 7947)	1
#   (0, 12402)	1
#   (0, 13386)	1
#   (0, 19636)	2
#   (0, 3131)	1
#   (0, 5111)	1
#   (0, 17536)	1
#   (0, 16104)	1
#   (0, 18980)	1
#   (0, 5995)	1
#   (0, 15523)	1
#   (0, 18312)	1
#   (0, 19504)	1
#   (0, 11233)	1
#   (0, 6383)	1
#   :	:
#   (9999, 9387)	3
#   (9999, 999)	1
#   (9999, 7913)	1
#   (9999, 12983)	1
#   (9999, 15360)	1
#   (9999, 13480)	2
#   (9999, 19366)	1
#   (9999, 1526)	1
#   (9999, 17761)	1
#   (9999, 1372)	1
#   (9999, 16414)	1
#   (9999, 19244)	1
#   (9999, 12402)	2
#   (9999, 19636)	1
#   (9999, 19470)	2
#   (9999, 7214)	1
#   (9999, 9174)	1
#   (9999, 19924)	1
#   (9999, 15637)	1
#   (9999, 17779)	1
#   (9999, 17768)	5
#   (9999, 9403)	1
#   (9999, 1162)	1
#   (9999, 12488)	2
#   (9999, 11853)	2
# [u'00', u'000', u'007', u'00a', u'00am', u'00pm', u'01', u'02', u'03', u'03342', u'04', u'05', u'06', u'07', u'08', u'09', u'0buxoc0crqjpvkezo3bqog', u'0l', u'0tzg', u'10', u'100', u'1000', u'1000x', u'1001', u'100lbs', u'100s', u'100th', u'101', u'102', u'102729', u'1030', u'104', u'105', u'1070', u'107f', u'108', u'109', u'10am', u'10ish', u'10k', u'10min', u'10minut', u'10oz', u'10p', u'10pm', u'10th', u'10x', u'10yo', u'11', u'110', u'1100', u'111', u'111th', u'112', u'113', u'1130', u'114', u'1145', u'115', u'115th', u'116', u'117', u'118', u'11a', u'11am', u'11p', u'11pm', u'11th', u'11year', u'12', u'120', u'1200', u'12000', u'1202', u'123', u'124', u'125', u'128i', u'129', u'12a', u'12am', u'12k', u'12oz', u'12pm', u'12th', u'13', u'130', u'1300', u'13331', u'135', u'13th', u'13yr', u'14', u'140', u'147', u'149', u'14lbs', u'15', u'150', u'1500', u'150k', u'150mm', u'157', u'15am', u'15ft', u'15min', u'15pm', u'15th', u'16', u'160', u'1600', u'162', u'165', u'1664', u'169', u'16oz', u'16th', u'16thh', u'17', u'170', u'175', u'177', u'17cent', u'17p', u'17th', u'18', u'180', u'1800', u'184', u'1892', u'1895', u'1899', u'18th', u'19', u'1900', u'1910', u'1913', u'1920', u'1920s', u'1926', u'1928', u'1929', u'1930s', u'1940', u'19485', u'1950', u'1950s', u'1952', u'1955', u'1956', u'1960', u'1961', u'1962', u'1965', u'1968', u'1969', u'1970', u'1970s', u'1973', u'1978', u'1980', u'1980s', u'1983', u'1987', u'199', u'1990', u'1990s', u'1991', u'1992', u'1993', u'1994', u'1995', u'1996', u'1997', u'1998', u'1999', u'19chptx8ahwztpc5xiarfq', u'19th', u'1am', u'1b', u'1cent', u'1hour', u'1jzambgdea9yyvasa8rukq', u'1k', u'1min', u'1oz', u'1p', u'1paote8ys9ujup3u4djhiq', u'1pm', u'1st', u'1star', u'20', u'200', u'2000', u'2001', u'2002', u'2003', u'2004', u'2005', u'2006', u'2007', u'2008', u'2009', u'200lb', u'200lbs', u'201', u'2010', u'20100421', u'2011', u'2012', u'2013', u'202', u'205', u'20mbs', u'20mile', u'20min', u'20minut', u'20oz', u'20pm', u'20s', u'20th', u'20x', u'21', u'215', u'21st', u'22', u'220', u'2240', u'22oz', u'23', u'230', u'23a', u'23rd', u'24', u'2400', u'24hour', u'24hr', u'24hrs', u'24st', u'24th', u'25', u'250', u'2500hd', u'25b', u'25min', u'25oz', u'25th', u'26', u'260', u'2600', u'2608', u'2669', u'26oz', u'26th', u'27', u'270', u'272', u'275', u'27th', u'28', u'284', u'2852', u'29', u'2939', u'2983024079', u'299', u'29th', u'2am', u'2k', u'2lb', u'2mbps', u'2nd', u'2pac', u'2pm', u'2rd', u'2wice', u'2x', u'2x4', u'2xu', u'30', u'300', u'3000', u'30a', u'30am', u'30ish', u'30k', u'30min', u'30p', u'30pm', u'30s', u'30someth', u'30th', u'30x', u'31', u'311', u'312', u'316', u'32', u'320', u'325', u'32nd', u'32oz', u'33', u'33lb', u'33rd', u'34', u'340', u'3400', u'341', u'34th', u'35', u'350', u'3500', u'350ib', u'35c', u'35th', u'36', u'360', u'365', u'37', u'370', u'38', u'38th', u'39', u'399', u'39th', u'3am', u'3chicken', u'3d', u'3g', u'3k', u'3l', u'3lb', u'3lbs', u'3n9u549zse8up', u'3oz', u'3p', u'3pm', u'3rd', u'3s', u'3taco', u'3x', u'40', u'400', u'4000', u'400s', u'40ish', u'40k', u'40lm', u'40min', u'40pm', u'40s', u'40th', u'41', u'411', u'411247', u'4113416766', u'42', u'420', u'43', u'43rd', u'44', u'4458', u'44oz', u'44th', u'45', u'450', u'453990', u'45am', u'45min', u'45pm', u'45sec', u'46', u'4655', u'46th', u'47', u'470', u'475', u'48', u'480', u'48th', u'49', u'490', u'49er', u'49lb', u'49th', u'4am', u'4b', u'4cxbhzxxtmexf9krjmfviq', u'4f', u'4hr', u'4ish', u'4k', u'4oz', u'4p', u'4peak', u'4pm', u'4s', u'4star', u'4th', u'4ths', u'4x', u'4x6', u'50', u'500', u'500sq', u'505', u'50cent', u'50ft', u'50lb', u'50lm', u'50s', u'50x', u'51', u'5130', u'51pm', u'51st', u'52', u'5231', u'53', u'530', u'53pm', u'54', u'547', u'55', u'5500', u'56', u'57', u'57th', u'58', u'59', u'59th', u'5am', u'5gb', u'5h', u'5ish', u'5k', u'5l', u'5min', u'5minut', u'5nzmttmomgj_svixktm51q', u'5oz', u'5p', u'5pm', u'5s', u'5star', u'5th', u'5yo', u'60', u'600', u'6000', u'602', u'60f', u'60mile', u ...

# %%
#splitting training data and test data in 75% and 25% respectively
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.33, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6700,)
# (3300,)
# (6700,)
# (3300,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# This vectorizer breaks text into single words and bi-grams
# and then calculates the TF-IDF representation
vectorizer = TfidfVectorizer(ngram_range=(1,2))

# the 'fit' builds up the vocabulary from all the reviews
# while the 'transform' step turns each indivdual text into
# a matrix of numbers.
X_train_dtm = vectorizer.fit_transform(X_train)

# %%
X_train_dtm
# Out:
# <6700x313335 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1354637 stored elements in Compressed Sparse Row format>

# %%
X_test_dtm =vectorizer.transform(X_test)
X_test_dtm
# Out:
# <3300x313335 sparse matrix of type '<type 'numpy.float64'>'
# 	with 542460 stored elements in Compressed Sparse Row format>

# %%
from sklearn.svm import LinearSVC

# initialise the SVM classifier
clf2 = LinearSVC()
clf2.fit(X_train_dtm, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
y_pred=clf2.predict(X_test_dtm)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.54393939393939394
